# %%
from IPython.display import display, Math

# %%
display(Math('\\sigma = \\mu + x^{3\\pi}'))
# Out:
# $$\sigma = \mu + x^{3\pi}$$

# %%
display(Math('\\sqrt{2}\\sqrt{2}'))
# Out:
# $$\sqrt{2}\sqrt{2}$$

# %%
display(Math('\\text{The answer to this derivation is } 2e^{4\\pi + \\mu^{cos(2\\theta)}}'))
# Out:
# $$\text{The answer to this derivation is } 2e^{4\pi + \mu^{cos(2\theta)}}$$

# %%
data = [3.5, 4, 4.5]
avg = sum(data) / len(data)
print(avg)
# Out:
# 4.0

# %% [markdown]
# # Heading 1
#
# This is to explain what the hell you're doing and why.
#
# $$\sigma = \mu + x^{3\pi}$$

# %%
display(Math('4x + 5y - 8z = 17'))
# Out:
# $$4x + 5y - 8z = 17$$

# %%
display(Math('\\sin(2 \\pi ft + \\theta)'))
# Out:
# $$\sin(2 \pi ft + \theta)$$

# %%
display(Math('e = mc^2'))
# Out:
# $$e = mc^2$$

# %%
display(Math('\\frac{4 + 5x^2}{(1 + x)(1 - x)}'))
# Out:
# $$\frac{4 + 5x^2}{(1 + x)(1 - x)}$$
