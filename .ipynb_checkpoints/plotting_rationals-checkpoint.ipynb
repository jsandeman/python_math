# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = range(-3,4)
y = [(2 - n**2) for n in x]

plt.plot(x, y)
plt.show()

# %%
x = np.linspace(-4,4,200)
e = range(-1, 4)

for i in e:
    y = x**i
    plt.plot(x,y,label='$y = x^{%s}$' %i,linewidth=2)

plt.legend()
plt.xlim([x[0], x[-1]])
plt.ylim([-20,20])
plt.show()
