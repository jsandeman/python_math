# %% [markdown]
# # Sympy and LaTex: Bug hunt!

# %%
from IPython.display import display, Math

import sympy as sym
sym.init_printing()

# %%
mu,alpha = sym.symbols('mu,alpha')

expr = 2*sym.exp(mu**2/alpha)

display(Math( sym.latex(expr) ))
# Out:
# $$2 e^{\frac{\mu^{2}}{\alpha}}$$

# %%
Math('1234 + \\frac{3x}{\\sin(2\\pi t+\\theta)}')
# Out:
# $$1234 + \frac{3x}{\sin(2\pi t+\theta)}$$

# %%
a, b = sym.symbols('a b')
a = 3
b = 4

# answer should be 7
print(sym.sympify(a+b))
# Out:
# 7

# %%
x = sym.symbols('x')


display(sym.simplify(sym.Eq( 4*x - 2, 0 )))
# Out:
# 4⋅x - 2 = 0

# %%
# part 1 of 2

q,r = sym.symbols('q r')
q = x**2
r = x**2

display(q)
display(r)
# Out:
#  2
# x
#  2
# x

# %%
# part 2 of 2

q,r = sym.symbols('q,r')

q = sym.sympify('x^2')
r = sym.sympify('x**2')

display(q)
display(r)

sym.Eq(q,r)
# Out:
#  2
# x
#  2
# x
# True

# %%
x = sym.symbols('x')

equation = (4*x**2 - 5*x + 10)**(1/2)
display(Math(sym.latex(equation)))
equation.subs(x,3)
# Out:
# $$\left(4 x^{2} - 5 x + 10\right)^{0.5}$$
# 5.56776436283002

# %%
x,y = sym.symbols('x,y')

equation = 1/4*x*y**2 - x*(5*x + 10*y**2)**(3)
display(equation)
# Out:
#                            3
#         2     ⎛          2⎞
# 0.25⋅x⋅y  - x⋅⎝5⋅x + 10⋅y ⎠
