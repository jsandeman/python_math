# %%
from IPython.display import display, Math
import sympy as sym

# %%
from sympy.abc import x

term1 = 4*x + 5
term2 = x

expanded_term = sym.expand(term1 * term2)
display (Math( sym.latex(expanded_term )))
# Out:
# $$4 x^{2} + 5 x$$

# %%
term3 = x - 7

display(Math( sym.latex( term1 * term3)))
display(Math( sym.latex( sym.expand(term1 * term3 ))))
# Out:
# $$\left(x - 7\right) \left(4 x + 5\right)$$
# $$4 x^{2} - 23 x - 35$$

# %%
y = sym.symbols('y')

expr = x * (2 * y**2 + 5**x / x)

display(Math(sym.latex(expr)))
display(Math(sym.latex(sym.expand(expr))))
# Out:
# $$x \left(\frac{5^{x}}{x} + 2 y^{2}\right)$$
# $$5^{x} + 2 x y^{2}$$

# %%
# %whos
# Out:
# Variable        Type        Data/Info
# -------------------------------------
# Math            type        <class 'IPython.core.display.Math'>
# display         function    <function display at 0x7f201d4cfd90>
# expanded_term   Add         4*x**2 + 5*x
# expr            Mul         x*(5**x/x + 2*y**2)
# sym             module      <module 'sympy' from '/us<...>kages/sympy/__init__.py'>
# term1           Add         4*x + 5
# term2           Symbol      x
# term3           Add         x - 7
# x               Symbol      x
# y               Symbol      y

# %%
eq = (4 + x) * (2 - y)

for i in range(0, 3):
  for j in range(0, 3):
    ans = eq.subs([(x, i), (y, j)])
    display(Math('f(%g, %g) = %g' %(i, j, ans)))
# Out:
# $$f(0, 0) = 8$$
# $$f(0, 1) = 4$$
# $$f(0, 2) = 0$$
# $$f(1, 0) = 10$$
# $$f(1, 1) = 5$$
# $$f(1, 2) = 0$$
# $$f(2, 0) = 12$$
# $$f(2, 1) = 6$$
# $$f(2, 2) = 0$$
