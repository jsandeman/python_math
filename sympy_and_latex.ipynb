# %%
import sympy as sym
import numpy as np
from IPython.display import display, Math

sym.init_printing()

# %%
mu, alpha, sigma = sym.symbols('mu alpha sigma')

# %%
mu
# Out:
# μ

# %%
expr = sym.exp((mu - alpha)**2 / (2 * sigma**2))
display(expr)
# Out:
#          2
#  (-α + μ)
#  ─────────
#        2
#     2⋅σ
# ℯ

# %%
x, y = sym.symbols('x y')

# %%
eq = x * y**2

# %%
display(eq.subs({x: 7, y: 4}))
# Out:
# 112

# %%
eq2 = 3/x

leq2 = sym.latex(eq2)
display(Math(leq2))
# Out:
# $$\frac{3}{x}$$

# %%
expr = x**2 + 4
display(Math(sym.latex(expr)))
a = expr.subs(x, -2)
display(a)
# Out:
# $$x^{2} + 4$$
# 8

# %%
for i in range(-2,3):
  display(Math('\\text{With x = }%g \\quad \\Rightarrow \\quad %g^2 + 4 = %g' %(i, i, expr.subs(x, i))))
# Out:
# $$\text{With x = }-2 \quad \Rightarrow \quad -2^2 + 4 = 8$$
# $$\text{With x = }-1 \quad \Rightarrow \quad -1^2 + 4 = 5$$
# $$\text{With x = }0 \quad \Rightarrow \quad 0^2 + 4 = 4$$
# $$\text{With x = }1 \quad \Rightarrow \quad 1^2 + 4 = 5$$
# $$\text{With x = }2 \quad \Rightarrow \quad 2^2 + 4 = 8$$
